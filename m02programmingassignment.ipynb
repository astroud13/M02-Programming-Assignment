# %%
#Created by Austin Stroud
#Module 2 Programming Assignment
#Chapter 4 and 6 Programming Activities 

#4.1
#Choose number between 1 and 10 and assign the variable as secret
secret = 3

#Select another number between 1 and 10 and assign the variable guess
guess = 8

#Write conditional tests to print the appropriate message
if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")
    
#4.2
#Assign True or False to the variables small and green
small = False
green = True

#Write if/else statements to print which of these matches 
#choices: cherry, pea, watermelon, pumpkin
if small and not green:
    print("This sounds like it matches: cherry")
elif small and green:
    print("This sounds like it matches: pea")
elif not small and green:
    print("This sounds like it matches: watermelon")
else:
    print("This likely matches by process of elimination: pumpkin")
    
#6.1
#Define list
austins_list = [3, 2, 1, 0]
#Use for loop to iterate over each element and print it
for value in austins_list:
    print(value)

#6.2
#Assign value 7 to the variable guess_me
guess_me = 7

#Assign value 1 to the variable number
number = 1

#Write a while loop to compare number with guess_me
while number <= guess_me:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break  #Exit loop if number found
    else:
        print("oops")
        break  #Exit loop if number greater than guess_me
    number += 1  #Increment number at the end of loop

#6.3
#Assign value 5 to variable guess_me
guess_me = 5
#Use for loop to iterate over range(10)
for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break  #Exit loop if number found
    else:
        print("oops")
        break  #Exit loop if number greater than guess_me
# Out:
# too high
# This sounds like it matches: watermelon
# 3
# 2
# 1
# 0
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
# too low
# too low
# too low
# too low
# too low
# found it!
